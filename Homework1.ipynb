# %% [markdown]
# ## Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
print(2*n)
# Out:
# 10

# %% [markdown]
# ## Bài 2:
# Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân

# %%
a, b = map(float, input().split())
s = a*b - 3.14*(a/2)**2
print(f'Dien tich trong cay xung quanh la {f'{(s):.2f}'}')
# Out:
# Dien tich trong cay xung quanh la 2.86

# %% [markdown]
# ## Bài 3:
# Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input()
if ord(c) >= 97:
    print(chr(ord(c)-32))
else:
    print(chr(ord(c)+32))
# Out:
# a

# %% [markdown]
# ## Bài 4:
# Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c = input()
if (97 >= ord(c) >= 122) or (65 <= ord(c) <= 90) :
    print(f'{c} la ki tu alphabet')
else:
    print(f'{c} khong la ki tu alphabet')
# Out:
# @ khong la ki tu alphabet

# %% [markdown]
# ## Bài 5:
# Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input()
if ord(c) == 65:
    print('z')
else:
    print(chr(ord(c)+31))
# Out:
# z

# %% [markdown]
# ## Bài 6.
# Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a,b, c= map(float, input().split())
if ((a+b)>c and (a+c)>b and (c+b)>a):
    cv=(a+b+c)/2
    s=(cv*(cv-a)*(cv-b)*(cv-c))**0.5
    print(f'dien tich tam giac la {f'{(s):.1f}'}')
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
# dien tich tam giac la 6.0

# %% [markdown]
# ## Bài 7:
# Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
a = input()
print(a[4], a[8])
# Out:
# 1

# %% [markdown]
# ## Bài 8:
# Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:

# %%
name = input()
chisothangtruoc = int(input())
chisothangnay = int(input())
a = chisothangnay - chisothangtruoc
if a >= 401 :
    tien = (1.984*50 + 2.05*50 + 2.38*100 + 2.998*100 + 3.35*100 + 3.46*(a-401))*1.08
elif 301 <= a <= 400 :
    tien = (1.984*50 + 2.05*50 + 2.38*100 + 2.998*100 + 3.35*(a-300))*1.08
elif 201 <= a <= 300 :
    tien = (1.984*50 + 2.05*50 + 2.38*100 + 2.998*(a-200))*1.08
elif 101 <= a <= 200 :
    tien = (1.984*50 + 2.05*50 + 2.38*(a-100))*1.08
elif 51 <= a <= 100 :
    tien = (1.984*50 + 2.05*(a-50))*1.08
else:
    tien = 1.984*a*1.08
print(f'''Ho va ten : {name}
Tien phai tra la : {tien}''')
# Out:
# Ho va ten : Vu
# Tien phai tra la : 217.836

# %% [markdown]
# ## Một số bài tập khác

# %% [markdown]
# 1.Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.

# %%
n = int(input())
if n % 2 == 0:
    print(f'{n} la so chan')
else:
    print(f'n la so le')

# %% [markdown]
# 3. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra
# số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”

# %%
n = int(input())
if n % 5 == 0 and n % 3 == 0:
    print('True')
else:
    print('False')
# Out:
# True

# %% [markdown]
# 2. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra
# số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
if n % 5 ==0 and n % 2 != 0:
    print('True')
else:
    print('False')
# Out:
# False

# %% [markdown]
# 4. Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
n = int(input())
if n >= 18 :
    print("Du dieu kien")
else:
    print('Khong du dieu kien')
# Out:
# Du dieu kien

# %% [markdown]
# 5. So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo
# nếu hai số bằng nhau

# %%
a, b = map(float, input().split())
if a == b:
    print('Hai so bang nhau')
elif a > b:
    print(f'{a}')
else:
    print(f'{b}')

# %% [markdown]
# 6. Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm tra xem ký tự đó là chữ cái hay số.

# %%
a = input()
if (97 <= ord(a) <= 122) or (65 <= ord(a) <= 90):
    print(f'{a} la chu')
elif 48 <= ord(a) <= 57:
    print(f'{a} la so')
else:
    print(f'{a} ko la chu hay so')
# Out:
# 6 la so

# %% [markdown]
# 7. Bài tập 5: Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc:
# >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
diem = float(input())
if diem >= 8:
    print(f'Hoc luc gioi')
elif 6.5 <= diem < 8:
    print(f'Hoc luc kha')
elif 5 <= diem < 6.5:
    print(f'Hoc luc trung binh')
else:
    print(f'Hoc luc yeu')
# Out:
# Hoc luc kha

# %% [markdown]
# 8. Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4
# nhưng không chia hết cho 100)

# %%
nam = int(input())
if nam % 400 == 0 or ( nam % 4 ==0 and nam % 100 != 0) :
    print(f'{nam} la nam nhuan')
else:
    print(f'{nam} la nam khong nhuan')
# Out:
# 2014 la nam khong nhuan

# %% [markdown]
# 9. Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số
# tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
so = int(input())
match so:
    case 0:
        print('Khong')
    case 1:
        print('Mot')
    case 2:
        print('Hai')
    case 3:
        print('Ba')
    case 4:
        print('Bon')
    case 5:
        print('Nam')
    case 6:
        print('Sau')
    case 7:
        print('Bay')
    case 8:
        print('Tam')
    case 9:
        print('Chin')
# Out:
# Tam

# %% [markdown]
# 10.Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >= 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
diem = float(input())
if diem >= 4 :
    print('Qua mon')
else:
    print('Hoc lai')

# %% [markdown]
# 11.Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm
# hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
nam = int(input())
tuoi = 2025 - nam
if tuoi >= 18 :
    print('Nguoi do da du tuoi')
else:
    print('Nguoi do chua du tuoi')
print(f'Nguoi do {tuoi} tuoi')
# Out:
# Nguoi do chua du tuoi
# Nguoi do 15 tuoi
