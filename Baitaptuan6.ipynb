# %% [markdown]
# ## W6A1
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng
# giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
lst = list(map(int, input().split()))
lst2 = []
for c in lst:
    if c not in lst2:
        lst2.append(c)
print(lst2)
# Out:
# [10, 9, 8, 7]

# %% [markdown]
# ## W6A2
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị
# trí i), giữ nguyên thứ tự

# %%
x = list(map(int, input().split()))
lst = []
tong = 0
for i in range(0, len(x)):
    tong += x[i]
    lst.append(tong)
print(lst)

# %% [markdown]
# ## W6A3
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp
# xếp.)

# %%
tup = tuple(map(int, input().split()))
k = int(input())
# lst1 = []
# lst2 = []
# for i in range(k):
#     lst1.append(tup[i])
# for c in tup[k:]:
#     lst2.append(c)
# print(lst2 + lst1)
print(tup[k:] + tup[:k])
# Out:
# (-4, -1, -2, -3)

# %% [markdown]
# ## W6A4
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key
# lặp lại, thêm vào list của key đó

# %%
# ln = input().split()
# dict1 = {}
# for c in ln:
#     k, v = c.split(":")
#     if k not in dict1.keys():
#         dict1[k] = [v]
#     else:
#         dict1[k].append(v)
# print(dict1)
ln = input().split()
dict1 = {}
for c in ln:
    k, v = c.split(":")
    if k not in dict1.keys():
        dict1[k] = [v]
    else:
        dict1[k].append(v)
print(dict1)
# Out:
# {'id': ['1', '2', '1']}

# %% [markdown]
# ## W6A5
# Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ...,
# 'zeros': ...} (đếm số >0, <0, =0)

# %%
lst = list(map(int, input().split()))
duong = 0
am = 0
ko = 0
for c in lst:
    if c>0:
        duong += 1
    elif c<0:
        am += 1
    elif c == 0:
        ko += 1
dict = {'positives':duong, 'negatives':am, 'zeros':ko}
print(dict)

# %%
lst = list(map(int, input().split()))
duong = 0
am = 0
ko = 0
for n in lst:
    if n>0:
        duong += 1
    elif n<0:
        am += 1
    else:
        ko += 1
dict = {'positives': duong, 'negatives': am, 'zeros': ko}
print(dict)
# Out:
# {'positives': 2, 'negatives': 2, 'zeros': 2}

# %% [markdown]
# ## W6A6
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng
# các số trong list đó.

# %%
lst = list(map(int, input().split()))
s = 0
for c in lst:
    s += c
print(s)

# %% [markdown]
# ## W6A7
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và
# tuple đảo ngược

# %%
tup = tuple(map(int, input().split()))
print(f'{tup[0]}, {tup[-1]}, {tup[::-1]}')
# Out:
# 1, 5, (5, 4, 3, 2, 1)

# %% [markdown]
# ## W6A8
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện
# của từng chuỗi và lưu vào dictionary.

# %%
lst = list(map(str, input().split()))
dict = {}
for ch in lst:
    dict[ch] = dict.get(ch, 0) + 1
print(dict)
# Out:
# {'a': 3, 'b': 1, 'c': 1}

# %% [markdown]
# ## W6A9
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một
# dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ
# được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới
# theo thứ tự từ điển tăng dần của key

# %%
d1 = input().split()
d2 = input().split()
dict1 = {}
dict2 = {}
for c in d1:
    k, v = c.split(":")
    dict1[k] = int(v)
for n in d2:
    k2, v2 = n.split(":")
    dict2[k2] = int(v2)
    
for key in dict1.keys():
    dict2[key] = dict2.get(key, 0) + dict1[key]
print(dict(sorted(dict2.items())))
# Out:
# {'x': 1}

# %% [markdown]
# ## W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên
# dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là
# một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh
# sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được
# sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
lst = list(map(int, input().split()))
k = int(input())
lst1 = []
for i in range(0,len(lst)-1):
    for j in range(i+1,len(lst)):
        if lst[i]+lst[j] == k:
            tup = (lst[i], lst[j])
            if tup not in lst1:
                lst1.append(tup)
print(lst1)
# Out:
# []

# %% [markdown]
# ## W6A11
# [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
tup = tuple(map(int, input().split()))
lst1 = []
lst2 = []
for ch in tup:
    if ch %2 == 0:
        lst1.append(ch)
    else:
        lst2.append(ch)
tup1 = tuple(lst1)
tup2 = tuple(lst2)
print(tup1)
print(tup2)
# Out:
# (2, 4, 6)
# (1, 3, 5, 7)

# %% [markdown]
# ## W6A12
# [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list.
# Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất
# trong số đó.

# %%
lst1 = list(map(int, input().split()))
dict1 = {}
for ch in lst1:
    if ch in dict1:
        dict1[ch] += 1
    else:
        dict1[ch] = 1
max = 1
ans = None
for value, key in dict1.items():
    if (value > max) or (value == max and (ans is None or key > ans)):
        max = value
        ans = key
print(ans)
# Out:
# 1

# %% [markdown]
# ## W6A13
# [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo
# một dictionary mới bằng cách đảo ngược key và value của dictionary ban
# đầu. In ra dictionary mới.

# %%
d = input().split()
dictionary = {}
for ch in d:
    key, value = ch.split(":")
    dictionary[key] = value
print(dictionary)
dictionary1 = {}
for key, value in dictionary.items():
    dictionary1[value] = key
print(dictionary1)
# Out:
# {'a': '2', 'b': '3', 'c': '4', 'd': '5'}
# {'2': 'a', '3': 'b', '4': 'c', '5': 'd'}

# %% [markdown]
# ## W6A14 [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
lst1 = list(map(int, input().split()))
lst2 = list(map(int, input().split()))
lst = []
for n in lst1:
    for c in lst2:
        if n == c:
            lst.append(n)
print(lst)
# Out:
# [4, 5, 6]

# %% [markdown]
# ## W6A15
# [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp
# key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary
# mới

# %%
d = input().split()
dict2 = {}
dict1 = {}     
for ch in d:
    key, value = ch.split(":")
    dict1[key] = value
k = int(input())  
for key, value in dict1.items():
    value = int(value)
    if value > k:
        dict2[key] = value
        
print(dict2)
# Out:
# {'c': 4, 'd': 5, 'e': 6}

# %% [markdown]
# ## Bài tập bổ sung
# Cho 1 danh sách số nguyên các giá trị [0,9]. Liệt kê số lần xuất hiện của các số có trong danh sách
# VD [ 1 2 1 3 1 5 6 7 8]
# 1 : 3
# 2 : 1
# 3 : 1
# 5 : 1
# 6 : 1
# 7 : 1
# 8 : 1

# %%
lst = list(map(int, input().split()))
dict = {}
for ch in lst:
    if ch in dict:
        dict[ch] += 1
    else:
        dict[ch] = 1
print(dict)
# Out:
# {1: 3, 2: 1, 3: 1, 5: 1, 6: 1, 7: 1, 8: 1}

# %% [markdown]
# ## BTBS
# Cho 1 chuỗi chỉ gồm gồm các kí tự chữ cái thường, liệt kê số lần xuất hiện các kí tự xuất hiện trong chuỗi

# %%
s = input()
dict = {}
for ch in s:
    if ch in dict:
        dict[ch] += 1
    else:
        dict[ch] = 1
print(dict)
# Out:
# {'a': 3, 'b': 5, 'c': 1, 's': 1, 'd': 1}
